# %%
from importer import import_houses

# %%
df = import_houses()

# %%
df.head()
# Out:
#    id property_type                property_name       price  \
# 0   1    Desarrollo         CGLV -BORGO FRASSINO   6236750.0
# 1   2    Desarrollo   Residencias Parque Acacias  12850000.0
# 2   3    Desarrollo        Villas de Santa Maria   4990000.0
# 3   4    Desarrollo  Villas del Bicentenario I I   7260000.0
# 4   5    Desarrollo     La Magdalena Residencial   5280000.0
#
#                                              address        town  \
# 0  Miguel Miramón 107, Lomas Verdes 6a Sección, N...   Naucalpan
# 1  Margaritas 55, Florida, Alvaro Obregón, Distri...  Cuauhtémoc
# 2  Cipres 100, Santa María, San Mateo Atenco, Est...      Toluca
# 3  Emiliano Zapata \tSur \t 843 Sur, Llano Grande...      Toluca
# 4  A San Bartolo 500, Santa María Magdalena Ocoti...      Toluca
#
#               state country  \
# 0  Estado De México  Mexico
# 1  Ciudad de México  Mexico
# 2  Estado De México  Mexico
# 3  Estado De México  Mexico
# 4  Estado De México  Mexico
#
# ...
